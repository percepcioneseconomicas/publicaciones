# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
data = pd.read_csv('https://raw.githubusercontent.com/percepcioneseconomicas/indices/main/GFK%20ADIMARK%20IPEC.csv', parse_dates=True, dayfirst=True, index_col='Fecha')
data.columns = ['sepa', 'sena', 'senf1', 'senf5', 'cons', 'ipec']
data
# Out:
#              sepa   sena  senf1  senf5   cons   ipec
# Fecha
# 2002-03-01  35.00  38.00  51.00  33.00  40.00  37.30
# 2002-04-01  37.00  36.00  51.00  31.00  36.00  36.30
# 2002-05-01  38.00  37.00  54.00  33.00  38.00  38.23
# 2002-06-01  38.00  37.00  49.00  31.00  41.00  37.03
# 2002-07-01  37.00  36.00  47.00  30.00  44.00  36.52
# ...           ...    ...    ...    ...    ...    ...
# 2020-10-01  26.12  23.70  38.32  27.28  34.18  29.92
# 2020-11-01  26.59  25.50  41.40  25.86  28.38  29.55
# 2020-12-01  26.92  26.18  37.70  22.05  36.37  29.85
# 2021-01-01  27.73  27.05  37.06  23.19  32.41  29.49
# 2021-02-01  29.12  30.43  43.85  23.49  32.97  31.97
#
# [228 rows x 6 columns]

# %%
ax = data['ipec'].plot(label='IPEC', linewidth=1.5, figsize=(8,5))
ax.axhline(50, label='IPEC=50', ls='--', color='green', linewidth=0.8)
ax.axhline(data['ipec'].median(), label='Mediana', ls='--', color='red', linewidth=0.8)
plt. legend()
plt.show()

# %%
data[['sepa', 'sena', 'cons']].plot(linewidth=0.5, figsize=(8,5))
plt.show()

# %%
data[['senf1', 'senf5']].plot(linewidth=0.5, figsize=(8,5))
plt.show()
